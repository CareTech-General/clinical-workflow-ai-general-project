# %%
# ── Hospital Readmission Risk Prediction (2026) ───────────────────────────────
# Source: https://www.kaggle.com/datasets/algozee/hospital-readmission-risk-prediction-2026
# Task:   Predict 30-day hospital readmission
# File:   verify exact filename on the Kaggle page
# ─────────────────────────────────────────────────────────────────────────────

# TODO: import any additional libraries you need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CSV_FILE   = 'clinical-workflow-ai-general-project\data\hospital_readmission_risk_dataset_2026_v1_18000rows.csv'  # TODO: verify exact filename on Kaggle
TARGET_COL = 'readmitted'                      # TODO: verify target column name on Kaggle

df = pd.read_csv(CSV_FILE)

print("Shape:", df.shape)
print("\nAll columns:", df.columns.tolist())
print("\nData types:\n", df.dtypes)
df.head()

# %%
# Quick look — run this before anything else
print("Missing values:")
print(df.isnull().sum())

print(f"\nTarget '{TARGET_COL}' distribution:")
print(df[TARGET_COL].value_counts())
print(f"Readmission rate: {df[TARGET_COL].mean():.1%}")

# Things to think about:
# - What does 30-day readmission mean, and why do hospitals want to predict it?
# - Are any features leakage (i.e. only known after readmission, not at discharge)?

# %%
# ── EDA ───────────────────────────────────────────────────────────────────────
# TODO: explore the data
# Ideas:
# - Readmission rate by diagnosis, age group, insurance type
# - Look at length of stay, number of medications, number of procedures
# - Check class balance

# your code here

# %%
# ── Preprocessing ─────────────────────────────────────────────────────────────
# TODO: prepare data for modeling
# Things to consider:
# - Drop ID columns
# - Encode categorical features (diagnosis codes, insurance type, discharge disposition)
# - Handle class imbalance if needed
# - Feature scaling

# your code here

# %%
# ── Model ─────────────────────────────────────────────────────────────────────
# TODO: build and train your model

# your code here

# %%
# ── Evaluation ────────────────────────────────────────────────────────────────
# TODO: evaluate your model
# Suggested metrics:
# - ROC-AUC
# - Precision, Recall, F1
# - Confusion matrix

# Discussion:
# - Hospitals are penalized financially for high readmission rates.
#   How does that affect which metric you'd optimize for?
# - What interventions could a hospital take based on your model's predictions?

# your code here
