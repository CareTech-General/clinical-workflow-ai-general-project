# %%
# ── Stroke Prediction Dataset ─────────────────────────────────────────────────
# Source: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
# Task:   Predict whether a patient will have a stroke
# File:   healthcare-dataset-stroke-data.csv
# ─────────────────────────────────────────────────────────────────────────────

# TODO: import any additional libraries you need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("clinical-workflow-ai-general-project\data\healthcare-dataset-stroke-data.csv" na_values=['N/A', 'Unknown'])

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nData types:\n", df.dtypes)
df.head()

# %%
# Quick look — run this before anything else
print("Missing values:")
print(df.isnull().sum())

print("\nTarget distribution (stroke):")
print(df['stroke'].value_counts())
print(f"Positive class rate: {df['stroke'].mean():.1%}")

# Things to think about:
# - Which column has missing values? How will you handle them?
# - Only ~5% of rows are stroke cases. Why does this matter for modeling?

# %%
# ── EDA ───────────────────────────────────────────────────────────────────────
# TODO: explore the data
# Ideas:
# - Plot distributions of age, bmi, avg_glucose_level
# - Compare stroke vs non-stroke groups across key features
# - Look at categorical features: gender, work_type, smoking_status

# your code here

# %%
# ── Preprocessing ─────────────────────────────────────────────────────────────
# TODO: prepare data for modeling
# Things to handle:
# - Missing values (hint: bmi has ~200 missing rows)
# - Encode categorical columns (gender, work_type, smoking_status, etc.)
# - Address class imbalance (consider SMOTE or class_weight)
# - Train/test split

# your code here

# %%
# ── Model ─────────────────────────────────────────────────────────────────────
# TODO: build and train your model

# your code here

# %%
# ── Evaluation ────────────────────────────────────────────────────────────────
# TODO: evaluate your model
# Suggested metrics for imbalanced data:
# - ROC-AUC
# - Precision, Recall, F1
# - Confusion matrix
# Note: accuracy alone is misleading here — why?

# Discussion:
# - What metric matters most for stroke prediction in a clinical setting?
# - Would you rather have more false positives or false negatives? Why?

# your code here
